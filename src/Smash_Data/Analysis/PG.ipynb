# %% [markdown]
# # Set Up

# %%
from dutil import parentizeCWD
parentizeCWD(n=2)
# Out:
# Directory unchanged at c:\Users\soph\PVV\Projects\Smash\SMASH\src

# %%
# Imports
## Dependencies
import os
from pathlib import Path
import peppi_py as pp


## Ours
import constants_and_config.gconsants as gconsants

# %% [markdown]
# ## Data

# %%
slippi_folder_path = (Path(gconsants.DATA_FOLDER) /'melee_public_slp_dataset_v2'/ 'training_data')
exampleFiles = os.listdir(slippi_folder)

# %%
pp.read_slippi(str(slippi_folder_path/exampleFiles[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 pp.read_slippi(slippi_folder_path/exampleFiles[0])
#
# TypeError: argument 'path': 'WindowsPath' object cannot be converted to 'PyString'
