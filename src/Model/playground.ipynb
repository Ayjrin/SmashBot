# %%
import slippi
from slippi import Game, event
import os

# %%
file_folder = "Data/Subset"
slps = os.listdir(file_folder)
test_game = file_folder + "/" + slps[0]
print(test_game)
# Out:
# Data/Subset/01_14_37.489Z [EASY] Fox + [=P] Marth (YS).slp

# %%
Game(test_game).frames[400].ports[3].leader.pre.buttons
# Out:
# Buttons(
#     logical=0b10000000000010000000000000100000:TRIGGER_ANALOG|JOYSTICK_RIGHT|R,
#     physical=0b100000:R)

# %%
print(Game(test_game).frames[946].ports[3].leader.post)
# Out:
# Post(
#     airborne=True,
#     character=18:MARTH,
#     combo_count=1,
#     damage=54.03,
#     direction=-1:LEFT,
#     flags=0b100:4,
#     ground=None,
#     hit_stun=0.00,
#     jumps=1,
#     l_cancel=None,
#     last_attack_landed=20:UP_SPECIAL,
#     last_hit_by=1,
#     position=(24.57, 40.48),
#     shield=60.00,
#     state=66:ATTACK_AIR_F,
#     state_age=8.00,
#     stocks=4)
